# %%
#no_test
#dependencies

#nlp packages
import spacy
from spacy.util import minibatch, compounding

#manipulation of tables/arrays
import pandas as pd
import numpy as np

#internal imports
from ssda_nlp.collate import *
from ssda_nlp.split_data import *
from ssda_nlp.modeling import *
from ssda_nlp.model_performance_utils import *
from ssda_nlp.xml_parser import *
from ssda_nlp.relationships import *
from ssda_nlp.unstructured2markup import *

# %%
#no_test

trained_model = load_model('models/mat_baut_1', language="es", verbose='True')
# Out:
# Loaded model 'models/mat_baut_1'

# %%
#no_test

demo_df = parse_xml_v2("transcriptions\\15834.xml")
demo_df.head()
# Out:
#                                             vol_titl vol_id fol_id  \
# 0  Libro 1 de Bautismos de Pardos y Morenos, 1719...  15834   1033
# 1  Libro 1 de Bautismos de Pardos y Morenos, 1719...  15834   1033
# 2  Libro 1 de Bautismos de Pardos y Morenos, 1719...  15834   1033
# 3  Libro 1 de Bautismos de Pardos y Morenos, 1719...  15834   1033
# 4  Libro 1 de Bautismos de Pardos y Morenos, 1719...  15834   1034
#
#                                                 text entry_no
# 0  [margin]: Juana. Esc.va Domingo veinte y dos d...   1033-1
# 1  [margin]: Paula. Esc.a Juebes veinte y tres de...   1033-2
# 2  [margin]: Maria Esc.a Miercoles prim.o de feb....   1033-3
# 3  [margin]: Bernardo Esc.vo Domingo nueve de Abr...   1033-4
# 4  [margin]: Fran.co Esc.vo [roto] Abril de mil s...   1034-1

# %%
#no_test

ent_preds_df, metrics_df, per_ent_metrics = test_model(trained_model, demo_df, "entry_no", "text", score_model=False)

# %%
#no_test

pd.set_option("display.max_rows", None, "display.max_columns", None)
ent_preds_df.head(200)
# Out:
#     entry_no                                        pred_entity pred_label  \
# 0     1033-1                                              Juana        PER
# 1     1033-1                                             Esc.va       CHAR
# 2     1033-1             Domingo veinte y dos de [roto] y nueve       DATE
# 3     1033-1                                   Thomas de Orvera        PER
# 4     1033-1                                    Juana de nacion        PER
# 5     1033-1                                               Mina       CHAR
# 6     1033-1                                            esclava       CHAR
# 7     1033-1                              Juan Joseph de Justis        PER
# 8     1033-1                                               P.P.        REL
# 9     1033-1                                     Joseph Salcedo        PER
# 10    1033-1                                    Ana de Santiago        PER
# 11    1033-1                                   Thomas de Orvera        PER
# 12    1033-2                                              Paula        PER
# 13    1033-2                                              Esc.a       CHAR
# 14    1033-2  Juebes veinte y tres de feb.o de mil sietec.to...       DATE
# 15    1033-2                                   Thomas de Orvera        PER
# 16    1033-2                                              Paula        PER
# 17    1033-2                                                 h.       CHAR
# 18    1033-2                                        Juan Joseph        PER
# 19    1033-2                                      Maria Josepha        PER
# 20    1033-2                                              esc.s       CHAR
# 21    1033-2                 Capitan D. Luis Hurtado de Mendoza        PER
# 22    1033-2                                            Padrino        REL
# 23    1033-2                                    Bartholome Rixo        PER
# 24    1033-2                                   Thomas de Orvera        PER
# 25    1033-3                                              Maria        PER
# 26    1033-3                                              Esc.a       CHAR
# 27    1033-3  Miercoles prim.o de feb.o de mil siete.tos y d...       DATE
# 28    1033-3                                   Thomas de Orvera        PER
# 29    1033-3                                              Maria        PER
# 30    1033-3                                                 h.       CHAR
# 31    1033-3                                              Juan,        PER
# 32    1033-3                                            Josepha        PER
# 33    1033-3                                              esc.s       CHAR
# 34    1033-3                            Capitan Antonio Benites        PER
# 35    1033-3                                            Madrina        REL
# 36    1033-3                                      Ysabel Mendez        PER
# 37    1033-3                                   Thomas de Orvera        PER
# 38    1033-4                                           Bernardo        PER
# 39    1033-4                                             Esc.vo       CHAR
# 40    1033-4  Domingo nueve de Abril de mil sietectos y diez...       DATE
# 41    1033-4                                   Thomas de Orvera        PER
# 42    1033-4                                           Bernardo        PER
# 43    1033-4                                              negro       CHAR
# 44    1033-4                                             adulto       CHAR
# 45    1033-4                                           carabali       CHAR
# 46    1033-4                                              esc.o       CHAR
# 47    1033-4                           D. Juan Joseph de Justis        PER
# 48    1033-4                                                 P.        REL
# 49    1033-4                                  Andres de Morales        PER
# 50    1033-4                                   Thomas de Orvera        PER
# 51    1034-1                                            Fran.co        PER
# 52    1034-1                                             Esc.vo       CHAR
# 53    1034-1   [roto] Abril de mil sietec.tos y diez, y nueve [       DATE
# 54    1034-1             Th[roto]mas de [roto]vera bap[roto]izé        PER
# 55    1034-1                                            Fran.co        PER
# 56    1034-1                                              negro       CHAR
# 57    1034-1                                             adulto       CHAR
# 58    1034-1                                               temo       CHAR
# 59    1034-1                                              esc.o       CHAR
# 60    1034-1                       D. Ju[roto] Joseph de Justis        PER
# 61    1034-1                                                 P.        REL
# 62    1034-1                                       Pedro Suares        PER
# 63    1034-1                                   Thomas de Orvera        PER
# 64    1034-2                                              Ant.o        PER
# 65    1034-2                                             Esc.vo       CHAR
# 66    1034-2  Domingo nueve de Abril de mil sietec.tos y die...       DATE
# 67    1034-2                                   Thomas de Orvera        PER
# 68    1034-2                                              Ant.o        PER
# 69    1034-2                                              negro       CHAR
# 70    1034-2                                             adulto       CHAR
# 71    1034-2                                           carabali       CHAR
# 72    1034-2                                              esc.o       CHAR
# 73    1034-2                           D. Juan Joseph de Justis        PER
# 74    1034-2                                                 P.        REL
# 75    1034-2                                     Joseph de Soto        PER
# 76    1034-2                                   Thomas de Orvera        PER
# 77    1034-3                                            Antonia        PER
# 78    1034-3                                             Esc.va       CHAR
# 79    1034-3  Domingo nueve de Abril de mil sietec.tos y die...       DATE
# 80    1034-3                                   Thomas de Orvera        PER
# 81    1034-3                                            Antonia        PER
# 82    1034-3                                              negra       CHAR
# 83    1034-3                                             adulta       CHAR
# 84    1034-3                                               mina       CHAR
# 85    1034-3                                             esc.va       CHAR
# 86    1034-3                           D. Ju.o Joseph de Justis        PER
# 87    1034-3                                                 P.        REL
# 88    1034-3                                     Joseph Salcedo        PER
# 89    1034-3                                   Thomas de Orvera        PER
# 90    1034-4                                          M.a Luisa        PER
# 91    1034-4                                             esc.va       CHAR
# 92    1034-4  Domingo nueve de Abril de mil sietec.tos y die...       DATE
# 93    1034-4                                   Thomas de Orvera        PER
# 94    1034-4                              Maria Luisa de nacion        PER
# 95    1034-4                                              negra       CHAR
# 96    1034-4                                             adulta       CHAR
# 97    1034-4                                              esc.a       CHAR
# 98    1034-4                           D. Ju.o Joseph de Justis        PER
# 99    1034-4                                                 P.        REL
# 100   1034-4                                  Jacinto de Castro        PER
# 101   1034-4                                   Thomas de Orvera        PER
# 102   1034-5                                                Ana        PER
# 103   1034-5                                           esc.va17       CHAR
# 104   1034-5  Domingo nueve de Abril de mil sietec.tos y die...       DATE
# 105   1035-1                                                Ana        PER
# 106   1035-1                                              negra       CHAR
# 107   1035-1                                             adulta       CHAR
# 108   1035-1                           D. Ju.o Joseph de Justis        PER
# 109   1035-1                                            madrina        REL
# 110   1035-1                                Ysabe[roto] Delgado        PER
# 111   1035-1                                   Thomas de Orvera        PER
# 112   1035-2                                            Theresa        PER
# 113   1035-2                                             esc.va       CHAR
# 114   1035-2  Domingo nueve de Abril de mil sietec.tos y die...       DATE
# 115   1035-2                                   Thomas de Orvera        PER
# 116   1035-2                                            Theresa        PER
# 117   1035-2                                              negra       CHAR
# 118   1035-2                                             adulta       CHAR
# 119   1035-2                                               mina       CHAR
# 120   1035-2                                             esc.va       CHAR
# 121   1035-2                           D. Juan Joseph de Justis        PER
# 122   1035-2                                                 P.        REL
# 123   1035-2                                                 P.        REL
# 124   1035-2                                Joseph Salcede Soto        PER
# 125   1035-2                                    Ana de Santiago        PER
# 126   1035-2                                   Thomas de Orvera        PER
# 127   1035-3                                            Antonio        PER
# 128   1035-3                                             esc.vo       CHAR
# 129   1035-3  Martes onze de Abril de mil sietec.tos y diez ...       DATE
# 130   1035-3                                   Thomas de Orvera        PER
# 131   1035-3                                              Ant.o        PER
# 132   1035-3                                              negro       CHAR
# 133   1035-3                                             adulto       CHAR
# 134   1035-3                                           carabali       CHAR
# 135   1035-3                                             esc.vo       CHAR
# 136   1035-3                          D. Ju.n. Joseph de Justis        PER
# 137   1035-3                                                 P.        REL
# 138   1035-3                                Pedro Montes de Oca        PER
# 139   1035-3                                   Thomas de Orvera        PER
# 140   1035-4                                  Franc.co de Paula        PER
# 141   1035-4                                              Esc.o       CHAR
# 142   1035-4  Domingo quatro de Junio de mil sietecientos i ...       DATE
# 143   1035-4               Padre Predicador fray Alonso Cabello        PER
# 144   1035-4                                          religioso       CHAR
# 145   1035-4                                   Fran.co de Paula        PER
# 146   1035-4                                              negro       CHAR
# 147   1035-4                                             adulto       CHAR
# 148   1035-4                                            esclavo       CHAR
# 149   1035-4                               D. Juo J.e de Justis        PER
# 150   1035-4                                            Padrino        REL
# 151   1035-4                                              Pablo        PER
# 152   1035-4                                               esco       CHAR
# 153   1035-4                                      Sargto Abalos        PER
# 154   1035-4                                   Thomas de Orvera        PER
# 155   1036-1                                               Juan        PER
# 156   1036-1                                             esc.vo       CHAR
# 157   1036-1  Sabado veinte y quatro de Junio de mil sietect...       DATE
# 158   1036-1                             Joseph Lopez de Cuella        PER
# 159   1036-1                                               Juan        PER
# 160   1036-1                                              negro       CHAR
# 161   1036-1                                             adulto       CHAR
# 162   1036-1                                D. Thomas de Orvera        PER
# 163   1036-1                                                 P.        REL
# 164   1036-1                           Ygnacio Joseph de Loyola        PER
# 165   1036-1                                   Thomas de Orvera        PER
# 166   1036-2                                            Vicente        PER
# 167   1036-2                                             esc.vo       CHAR
# 168   1036-2  Domingo dos de Julio de mil sietec.tos y diez ...       DATE
# 169   1036-2                                                 P.        REL
# 170   1036-2                                 fray Joseph Hern.z        PER
# 171   1036-2                                          religioso       CHAR
# 172   1036-2                                            Vicente        PER
# 173   1036-2                                               Mina       CHAR
# 174   1036-2                                             adulto       CHAR
# 175   1036-2                                             esc.vo       CHAR
# 176   1036-2                          Cap.n D.n Bruno Cavallero        PER
# 177   1036-2                                                 P.        REL
# 178   1036-2                                   Thomas de Orvera        PER
# 179   1036-3                                             Joseph        PER
# 180   1036-3                                             esc.vo       CHAR
# 181   1036-3  Domingo dos de Julio de mil sietec.tos y diez,...       DATE
# 182   1036-3                                                 P.        REL
# 183   1036-3                                                fr.        PER
# 184   1036-3                                      Joseph Hern.z        PER
# 185   1036-3                                          religioso       CHAR
# 186   1036-3                                             Joseph        PER
# 187   1036-3                                              negro       CHAR
# 188   1036-3                                             adulto       CHAR
# 189   1036-3                                            malagas       CHAR
# 190   1036-3                                             esc.vo       CHAR
# 191   1036-3                          Cap.n D.n Bruno Cavallero        PER
# 192   1036-3                                            ingen.o       CHAR
# 193   1036-3                                                 P.        REL
# 194   1036-3                              Cap.n D. Man.l Chacon        PER
# 195   1036-3                                   Thomas de Orvera        PER
# 196   1036-4                                             Ysabel        PER
# 197   1036-4                                             Esc.va       CHAR
# 198   1036-4  Domingo treinta de Julio de mil sietec.tos y d...       DATE
# 199   1036-4                             Joseph Lopez de Cuella        PER
#
#     pred_start pred_end
# 0           10       15
# 1           17       23
# 2           24       62
# 3           66       82
# 4          121      136
# 5          137      141
# 6          142      149
# 7          159      180
# 8          192      196
# 9          197      211
# 10         214      229
# 11         263      279
# 12          10       15
# 13          17       22
# 14          23       86
# 15          90      106
# 16         145      150
# 17         151      153
# 18         162      173
# 19         177      190
# 20         191      196
# 21         201      235
# 22         243      250
# 23         251      266
# 24         290      306
# 25          10       15
# 26          16       21
# 27          22       79
# 28          83       99
# 29         136      141
# 30         142      144
# 31         151      156
# 32         159      166
# 33         167      172
# 34         177      200
# 35         208      215
# 36         216      229
# 37         253      269
# 38          10       18
# 39          19       25
# 40          26       80
# 41          84      100
# 42         136      144
# 43         145      150
# 44         151      157
# 45         168      176
# 46         177      182
# 47         186      210
# 48         218      220
# 49         221      238
# 50         262      278
# 51          10       17
# 52          18       24
# 53          25       73
# 54          80      118
# 55         151      158
# 56         159      164
# 57         165      171
# 58         182      186
# 59         187      192
# 60         196      224
# 61         232      234
# 62         235      247
# 63         271      287
# 64          10       15
# 65          16       22
# 66          23       78
# 67          82       98
# 68         134      139
# 69         140      145
# 70         146      152
# 71         163      171
# 72         172      177
# 73         181      205
# 74         213      215
# 75         216      230
# 76         254      270
# 77          10       17
# 78          18       24
# 79          25       81
# 80          85      101
# 81         137      144
# 82         145      150
# 83         151      157
# 84         168      172
# 85         173      179
# 86         183      207
# 87         215      217
# 88         218      232
# 89         256      272
# 90          10       19
# 91          20       26
# 92          27       83
# 93          87      103
# 94         138      159
# 95         167      172
# 96         173      179
# 97         180      185
# 98         189      213
# 99         221      223
# 100        224      241
# 101        265      281
# 102         10       13
# 103         14       22
# 104         23       73
# 105         49       52
# 106         53       58
# 107         59       65
# 108         74       98
# 109        106      113
# 110        114      133
# 111        157      173
# 112         10       17
# 113         18       24
# 114         25       81
# 115         85      101
# 116        137      144
# 117        145      150
# 118        151      157
# 119        168      172
# 120        173      179
# 121        183      207
# 122        219      221
# 123        222      224
# 124        225      244
# 125        248      263
# 126        287      303
# 127         10       17
# 128         19       25
# 129         26       79
# 130         83       99
# 131        134      139
# 132        140      145
# 133        146      152
# 134        163      171
# 135        172      178
# 136        182      207
# 137        215      217
# 138        218      237
# 139        261      277
# 140         10       27
# 141         28       33
# 142         34       95
# 143         99      135
# 144        136      145
# 145        224      240
# 146        241      246
# 147        247      253
# 148        284      291
# 149        295      315
# 150        323      330
# 151        331      336
# 152        337      341
# 153        348      361
# 154        384      400
# 155         10       14
# 156         15       21
# 157         22       87
# 158         91      113
# 159        200      204
# 160        205      210
# 161        211      217
# 162        264      283
# 163        291      293
# 164        294      318
# 165        356      372
# 166         10       17
# 167         18       24
# 168         25       81
# 169         85       87
# 170         88      106
# 171        107      116
# 172        189      196
# 173        205      209
# 174        210      216
# 175        217      223
# 176        228      253
# 177        279      281
# 178        333      349
# 179         10       16
# 180         17       23
# 181         24       81
# 182         85       87
# 183         88       91
# 184         92      105
# 185        106      115
# 186        189      195
# 187        196      201
# 188        202      208
# 189        217      224
# 190        225      231
# 191        236      261
# 192        262      269
# 193        285      287
# 194        291      312
# 195        416      432
# 196         10       16
# 197         17       23
# 198         24       81
# 199         85      107
